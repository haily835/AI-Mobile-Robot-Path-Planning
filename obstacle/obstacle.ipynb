# %%
from obstacle_map import Map
import matplotlib.pyplot as plt
image_path = "./o2.png"

# %% [markdown]
# **Obstacle map 2**

# %%
plt.imshow(plt.imread("./o2.png"))

# %%
o2 = Map(image_path="./o2.png", grid_size=20)
o2.draw_coordinate_system()

# %%
o2 = Map(image_path="./o2.png", grid_size=10)
o2.draw_coordinate_system()

# %%
o2 = Map(image_path="./o2.png", grid_size=5)
o2.draw_coordinate_system()

# %%
# Create a Map instance
o3 = Map('./o3.png', grid_size=20)
o3.draw_coordinate_system()

# %%
o3 = Map('./o3.png', grid_size=40)
o3.draw_coordinate_system()
